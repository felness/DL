# %% [markdown]
# # Домашнее задание
#
# Градиентный спуск и Momentum своими руками.

# %% [markdown]
# ## Quiz

# %% [markdown]
# Найдите минимум функции вручную (на бумажке):
#
# $f(x) = x^2 - 30x + 1$
#
# В ответ запишите точку минимума, округленную до сотых.

# %% [markdown]
# Используем библиотеку sympy для того, чтобы вычислять производные различных функций (при помощи `sp.diff`).
#
# Ниже реализован метод одномерного градиентного спуска для нахождения минимума функции `f(x)`.

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x77f11a1c7590>: Failed to establish a new connection: [Errno -3] Временный сбой в разрешении имен')': /packages/d0/04/66be21ceb305c66a4b326b0ae44cc4f027a43bc08cac204b48fb45bb3653/sympy-1.10.1-py3-none-any.whl.metadata
#   Downloading sympy-1.10.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath>=0.19 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.10.1-py3-none-any.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.10.1

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')

# %% [markdown]
# При помощи градиентного спуска найдем минимум функции
# $f(x) = x^3 - 3x^2 + 4$.

# %%
def f(x):
  return x**3 - 3*x**2 + 4

# %%
def gradient_descent(x_start, learning_rate, epsilon, num_iterations):
    x_curr = x_start
    df_x = sp.diff(f(x)) # производная

    trace = []
    trace.append(x_curr)

    for i in range(num_iterations):
      x_new = x_curr - learning_rate * df_x.subs(x, x_curr)
      trace.append(x_new)

      if abs(x_new - x_curr) < epsilon:
        return x_curr, trace

      x_curr = x_new

    return x_curr, trace

# %% [markdown]
# Визуализируем процесс поиска минимума (красные точки) и найденный минимум (зеленая точка).

# %%
xmin, trace = gradient_descent(3, 0.01, 0.001, 100)

x_values = [x for x in np.arange(-5, 5, 0.1)]
f_values = [f(x) for x in x_values]

plt.figure(figsize=(10,10))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')

plt.plot(x_values, f_values)

plt.xlim([-3, 5])
plt.ylim([-5, 7])

plt.title('График функции f(x) c экстремумами и точками перегиба')

plt.xlabel('x')
plt.ylabel('f(x)')

trace_values = [f(x) for x in trace]
plt.scatter(trace, trace_values, c='red')
plt.scatter([xmin],[f(xmin)], c='green')

plt.show()

# %% [markdown]
# ## Quiz
#
# Запишите в ответ точку минимума, округленную до сотых.

# %%
xmin, trace = gradient_descent(3, 0.01, 0.001, 100)
print(round(xmin, 2))
# Out:
# 2.02

# %% [markdown]
# Модифицируйте функцию, осуществляющую метод градиентного спуска с семинара:
#
# * добавьте опцию останавливать метод, если абсолютное значение производной функции в точке < некоторого $\delta$ (delta добавьте в аргументы функции)
#
# * добавьте в возвращаемые значения метода число произведенных методом итераций

# %%
# не забудьте добавить в возвращаемые значения функции число произведенных методом итераций

def gradient_descent_modified(x_start, learning_rate, epsilon, num_iterations, delta=1e-3):
    x_curr = x_start
    df_x = sp.diff(f(x))

    trace = []
    trace.append(x_curr)

    for _ in range(num_iterations):
        derivative = df_x.subs(x, x_curr)

        if np.abs(derivative) < delta:
            return x_new, trace, _ +1

        x_new = x_curr - learning_rate * derivative
        trace.append(x_new)

        if abs(x_new - x_curr) < epsilon:
            return x_new, trace, _ +1

        x_curr = x_new

    return x_new, trace, num_iterations

# %% [markdown]
# ## Quiz
#
# Визуализируйте результат работы метода (как в коде выше) и с теми же гиперпараметрами.
#
# Также выведите на экран число произведенных итераций.
# Сколько итераций произвел метод до остановки?

# %%
xmin, trace, num_iter = gradient_descent_modified(3, 0.01, 0.001, 100)

x_values = [x for x in np.arange(-3, 5, 0.1)]
f_values = [f(x) for x in x_values]

plt.figure(figsize=(10,10))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')

plt.plot(x_values, f_values)

plt.xlim([-3, 5])
plt.ylim([-5, 7])

plt.title('График функции f(x) c экстремумами и точками перегиба')

plt.xlabel('x')
plt.ylabel('f(x)')

trace_values = [f(x) for x in trace]
plt.scatter(trace, trace_values, c='red')
plt.scatter([xmin],[f(xmin)], c='green')

plt.show()

# %%
print(num_iter)
# Out:
# 61

# %% [markdown]
# ## Quiz
#
# При каком начальном приближении модифицированная функция с гиперпараметрами
# * `learning_rate = 0.001`
# * `epsilon = 0.001`
# * `num_iterations = 100`
# * `delta = 1e-3`
#
# верно находит глобальный минимум функции
# $f(x) = (x+5)*(x+2)*(x-3)*(x-4)$?
#
# Варианты ответа:
#
# a) -1
#
# b) 1
#
# c) 3
#
# d) 7

# %%
def f(x):
    return (x + 5) * (x + 2) * (x - 3) * (x - 4)

# %%
learning_rate = 0.001
epsilon = 0.001
num_iterations = 100
delta = 1e-3
minim = 10000000
x_start = -1
xmin, trace, num_iter = gradient_descent_modified(x_start, learning_rate, epsilon, num_iterations, delta=1e-3)


x_values = [x for x in np.arange(-5, 6, 0.1)]
f_values = [f(x) for x in x_values]

plt.figure(figsize=(10,10))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')

plt.plot(x_values, f_values)

plt.xlim([-5, 6])
plt.ylim([-120, 150])

plt.title('График функции f(x) c экстремумами и точками перегиба')

plt.xlabel('x')
plt.ylabel('f(x)')

trace_values = [f(x) for x in trace]
plt.scatter(trace, trace_values, c='red')
plt.scatter([xmin],[f(xmin)], c='green')

plt.show()

# %% [markdown]
# Реализуйте модификацию метода градиентного спуска - Momentum:
#
# $$x_{new} = x_{old} - h_{new},$$
# $$h_{new} = \alpha\cdot h_{old} + \eta\cdot f'(x_{old})$$
#
# В коде ниже
# * $\eta$ обозначена как `learning_rate`
# * $\alpha$ обозначена как `momentum`.

# %%
def momentum_method(x_start, learning_rate, epsilon, num_iterations, momentum, delta=0.01):

    x_curr = x_start
    df_x = sp.diff(f(x))

    trace = []
    trace.append(x_curr)

    h_curr = 0
    h_trace = []
    h_trace.append(h_curr)

    for i in range(1, num_iterations):

        h_new = momentum * h_curr + learning_rate * df_x.subs(x, x_curr)
        x_new = x_curr - h_new

        trace.append(x_new)
        h_trace.append(h_new)

        if (abs(x_new - x_curr) < epsilon) or (abs(df_x.subs(x, x_new)) < delta):
            return x_new, trace, i + 1

        x_curr = x_new
        h_curr = h_new


    return x_curr, trace, num_iterations

# %% [markdown]
# Проверьте, решает ли Momentum проблему застревания в локальном минимуме?
#
# Используйте гиперпараметры из запуска выше и возьмите
# * `x_start = 7`
# * `momentum = 0.2`

# %%
learning_rate = 0.001
epsilon = 0.001
num_iterations = 100
delta = 1e-3
x_start = 7
monentum = 0.2
xmin, trace, num_iter = momentum_method(x_start, learning_rate, epsilon, num_iterations, monentum, delta )

x_values = [x for x in np.arange(-5, 6, 0.1)]
f_values = [f(x) for x in x_values]

plt.figure(figsize=(10,10))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')

plt.plot(x_values, f_values)

plt.xlim([-5, 6])
plt.ylim([-120, 150])

plt.title('График функции f(x) c экстремумами и точками перегиба')

plt.xlabel('x')
plt.ylabel('f(x)')

trace_values = [f(x) for x in trace]
plt.scatter(trace, trace_values, c='red')
plt.scatter([xmin],[f(xmin)], c='green')

plt.show()

# %%
print(round(xmin, 2))
# Out:
# 3.54

# %% [markdown]
# ## Quiz
#
# Выведите на экран значение найденной точки минимума с заданными гиперпараметрами, округленное до сотых.

# %% [markdown]
# Теперь запустите метод с гиперпараметрами:
#
# * `x_start = 7`
# * `momentum = 0.8`.
#
# Остальные значения гиперпараметров оставьте как и раньше.

# %%
learning_rate = 0.001
epsilon = 0.001
num_iterations = 100
delta = 1e-3
x_start = 7
monentum = 0.8
xmin, trace, num_iter = momentum_method(x_start, learning_rate, epsilon, num_iterations, monentum, delta )


x_values = [x for x in np.arange(-5, 6, 0.1)]
f_values = [f(x) for x in x_values]

plt.figure(figsize=(10,10))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')

plt.plot(x_values, f_values)

plt.xlim([-5, 6])
plt.ylim([-120, 150])

plt.title('График функции f(x) c экстремумами и точками перегиба')

plt.xlabel('x')
plt.ylabel('f(x)')

trace_values = [f(x) for x in trace]
plt.scatter(trace, trace_values, c='red')
plt.scatter([xmin],[f(xmin)], c='green')

plt.show()

# %%
print(round(xmin, 2))
# Out:
# -3.81

# %%
x = sp.Symbol('x')

def f(x):
    return x ** 2

# %%
def method_of_moment(x_start, learning_rate, num_iteraction, m, epsilon, delta=1e-3):
    tr = []
    
    x_curr = x_start
    
    h_curr = 0
    
    diff_x = sp.diff(f(x))
    
    tr.append(x_curr)
    
    for i in range(1, num_iteraction):
        h_new = m * h_curr + learning_rate * diff_x.subs(x, x_curr)
        
        x_new = x_curr - h_new
        
        if abs(x_new - x_curr ) < epsilon or abs(diff_x.subs(x, x_new)) < delta:
            return x_new, tr, i + 1
        x_curr = x_new
        
        h_curr = h_new
        
        tr.append(x_curr)
        
    return x_curr, tr, num_iteraction

# %%
x_min, treap, num = method_of_moment(2, 0.01, 100, 0.3, 0.0001)

plt.figure(figsize=(12, 9))
plt.axvline(0, c='black')

plt.axhline(0, c='black')

x_values = np.arange(-10, 11)

y_values = [f(x) for x in x_values]

plt.plot(x_values, y_values)

y_treap = [f(x) for x in treap]

plt.scatter(treap, y_treap , c='red')

plt.scatter([x_min], f(x_min), c='grey')

plt.xlim([-10, 10])
plt.ylim([-10, 80])
# Out:
# (-10.0, 80.0)

# %%
print(x_min)
# Out:
# 0.110705045372373

# %% [markdown]
# ## Quiz
#
# Выведите на экран значение найденной точки минимума с заданными гиперпараметрами, округленное до десятых.
